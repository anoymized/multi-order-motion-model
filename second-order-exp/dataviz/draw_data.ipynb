# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import scipy.stats as stats
import seaborn as sns
# set seaborn style


file_root_yj = os.path.abspath(os.path.join(os.getcwd(), "../data/participant2"))
file_root_ly = os.path.abspath(os.path.join(os.getcwd(), "../data/participant3"))
file_root_sun = os.path.abspath(os.path.join(os.getcwd(), "../data/participant1"))

def polar2cartesian(angle, radius):  # angle in rad (0-2pi)
    if angle > np.pi:
        angle -= 2 * np.pi
    x = radius * np.cos(angle)
    y = -radius * np.sin(angle)
    return x, y


def cartesian2polar(x, y):
    radius = np.sqrt(x ** 2 + y ** 2)
    angle = np.arctan2(-y, x)
    # if angle < 0:
    #     angle += 2 * np.pi
    angle = angle + (angle < 0) * 2 * np.pi
    return angle, radius

# %%
# read csv file
df_yj = pd.read_csv(file_root_yj + '/data.csv', encoding='utf-8')
df_ly = pd.read_csv(file_root_ly + '/data.csv', encoding='utf-8')
df_sun = pd.read_csv(file_root_sun + '/data.csv', encoding='utf-8')

df = df_sun

# %%
Avg_gt_X, Avg_gt_Y =  df['Avg_gt_X'], df['Avg_gt_Y']
Mod1_avg_res_X, Mod1_avg_res_Y = df['Mod1_avg_res_X'], df['Mod1_avg_res_Y']
Mod2_avg_res_X, Mod2_avg_res_Y = df['Mod2_avg_res_X'], df['Mod2_avg_res_Y']
Mod3_avg_res_X, Mod3_avg_res_Y = df['Mod3_avg_res_X'], df['Mod3_avg_res_Y']
Mod4_avg_res_X, Mod4_avg_res_Y = df['Mod4_avg_res_X'], df['Mod4_avg_res_Y']
Mod5_avg_res_X, Mod5_avg_res_Y = df['Mod5_avg_res_X'], df['Mod5_avg_res_Y']
Mod6_avg_res_X, Mod6_avg_res_Y = df['Mod6_avg_res_X'], df['Mod6_avg_res_Y']
Mod7_avg_res_X, Mod7_avg_res_Y = df['Mod7_avg_res_X'], df['Mod7_avg_res_Y']

Avg_gt_X, Avg_gt_Y = Avg_gt_X.values, Avg_gt_Y.values
Mod1_avg_res_X, Mod1_avg_res_Y = Mod1_avg_res_X.values, Mod1_avg_res_Y.values
Mod2_avg_res_X, Mod2_avg_res_Y = Mod2_avg_res_X.values, Mod2_avg_res_Y.values
Mod3_avg_res_X, Mod3_avg_res_Y = Mod3_avg_res_X.values, Mod3_avg_res_Y.values
Mod4_avg_res_X, Mod4_avg_res_Y = Mod4_avg_res_X.values, Mod4_avg_res_Y.values
Mod5_avg_res_X, Mod5_avg_res_Y = Mod5_avg_res_X.values, Mod5_avg_res_Y.values
Mod6_avg_res_X, Mod6_avg_res_Y = Mod6_avg_res_X.values, Mod6_avg_res_Y.values
Mod7_avg_res_X, Mod7_avg_res_Y = Mod7_avg_res_X.values, Mod7_avg_res_Y.values

# to numpy
Avg_gt_X, Avg_gt_Y = np.array(Avg_gt_X), np.array(Avg_gt_Y)
Mod1_avg_res_X, Mod1_avg_res_Y = np.array(Mod1_avg_res_X), np.array(Mod1_avg_res_Y)
Mod2_avg_res_X, Mod2_avg_res_Y = np.array(Mod2_avg_res_X), np.array(Mod2_avg_res_Y)
Mod3_avg_res_X, Mod3_avg_res_Y = np.array(Mod3_avg_res_X), np.array(Mod3_avg_res_Y)
Mod4_avg_res_X, Mod4_avg_res_Y = np.array(Mod4_avg_res_X), np.array(Mod4_avg_res_Y)
Mod5_avg_res_X, Mod5_avg_res_Y = np.array(Mod5_avg_res_X), np.array(Mod5_avg_res_Y)
Mod6_avg_res_X, Mod6_avg_res_Y = np.array(Mod6_avg_res_X), np.array(Mod6_avg_res_Y)
Mod7_avg_res_X, Mod7_avg_res_Y = np.array(Mod7_avg_res_X), np.array(Mod7_avg_res_Y)
avg_gt_xy = np.concatenate((Avg_gt_X, Avg_gt_Y))
avg_mod1_xy = np.concatenate((Mod1_avg_res_X, Mod1_avg_res_Y))
avg_mod2_xy = np.concatenate((Mod2_avg_res_X, Mod2_avg_res_Y))
avg_mod3_xy = np.concatenate((Mod3_avg_res_X, Mod3_avg_res_Y))
avg_mod4_xy = np.concatenate((Mod4_avg_res_X, Mod4_avg_res_Y))
avg_mod5_xy = np.concatenate((Mod5_avg_res_X, Mod5_avg_res_Y))
avg_mod6_xy = np.concatenate((Mod6_avg_res_X, Mod6_avg_res_Y))
avg_mod7_xy = np.concatenate((Mod7_avg_res_X, Mod7_avg_res_Y))

# cartesian to polar
Avg_gt_a, Avg_gt_v = cartesian2polar(Avg_gt_X, Avg_gt_Y)
Avg_gt_a = np.rad2deg(Avg_gt_a)
Mod1_avg_res_a, Mod1_avg_res_v = cartesian2polar(Mod1_avg_res_X, Mod1_avg_res_Y)
Mod2_avg_res_a, Mod2_avg_res_v = cartesian2polar(Mod2_avg_res_X, Mod2_avg_res_Y)
Mod3_avg_res_a, Mod3_avg_res_v = cartesian2polar(Mod3_avg_res_X, Mod3_avg_res_Y)
Mod4_avg_res_a, Mod4_avg_res_v = cartesian2polar(Mod4_avg_res_X, Mod4_avg_res_Y)
Mod5_avg_res_a, Mod5_avg_res_v = cartesian2polar(Mod5_avg_res_X, Mod5_avg_res_Y)
Mod6_avg_res_a, Mod6_avg_res_v = cartesian2polar(Mod6_avg_res_X, Mod6_avg_res_Y)
Mod7_avg_res_a, Mod7_avg_res_v = cartesian2polar(Mod7_avg_res_X, Mod7_avg_res_Y)

Mod1_avg_res_a, Mod2_avg_res_a, Mod3_avg_res_a, Mod4_avg_res_a, Mod5_avg_res_a, Mod6_avg_res_a, Mod7_avg_res_a, \
= np.rad2deg(Mod1_avg_res_a), np.rad2deg(Mod2_avg_res_a), \
np.rad2deg(Mod3_avg_res_a), np.rad2deg(Mod4_avg_res_a), np.rad2deg(Mod5_avg_res_a), np.rad2deg(Mod6_avg_res_a), \
np.rad2deg(Mod7_avg_res_a),


angle_diff = np.abs(Mod1_avg_res_a - Avg_gt_a)
Mod1_avg_res_a_ = Mod1_avg_res_a + 360 * ((angle_diff > 180) & (Mod1_avg_res_a < 180)) - 360 * ((angle_diff > 180) & (
        Mod1_avg_res_a > 180))  # TODO: check if this is correct
angle_diff = np.abs(Mod2_avg_res_a - Avg_gt_a)
Mod2_avg_res_a_ = Mod2_avg_res_a + 360 * ((angle_diff > 180) & (Mod2_avg_res_a < 180)) - 360 * ((angle_diff > 180) & (
        Mod2_avg_res_a > 180))  # TODO: check if this is correct
angle_diff = np.abs(Mod3_avg_res_a - Avg_gt_a)
Mod3_avg_res_a_ = Mod3_avg_res_a + 360 * ((angle_diff > 180) & (Mod3_avg_res_a < 180)) - 360 * ((angle_diff > 180) & (
        Mod3_avg_res_a > 180))  # TODO: check if this is correct
angle_diff = np.abs(Mod4_avg_res_a - Avg_gt_a)
Mod4_avg_res_a_ = Mod4_avg_res_a + 360 * ((angle_diff > 180) & (Mod4_avg_res_a < 180)) - 360 * ((angle_diff > 180) & (
        Mod4_avg_res_a > 180))  # TODO: check if this is correct
angle_diff = np.abs(Mod5_avg_res_a - Avg_gt_a)
Mod5_avg_res_a_ = Mod5_avg_res_a + 360 * ((angle_diff > 180) & (Mod5_avg_res_a < 180)) - 360 * ((angle_diff > 180) & (
        Mod5_avg_res_a > 180))  # TODO: check if this is correct
angle_diff = np.abs(Mod6_avg_res_a - Avg_gt_a)
Mod6_avg_res_a_ = Mod6_avg_res_a + 360 * ((angle_diff > 180) & (Mod6_avg_res_a < 180)) - 360 * ((angle_diff > 180) & (
        Mod6_avg_res_a > 180))  # TODO: check if this is correct
angle_diff = np.abs(Mod7_avg_res_a - Avg_gt_a)
Mod7_avg_res_a_ = Mod7_avg_res_a + 360 * ((angle_diff > 180) & (Mod7_avg_res_a < 180)) - 360 * ((angle_diff > 180) & (
        Mod7_avg_res_a > 180))  # TODO: check if this is correct



corr_uv_mod1 = np.corrcoef(avg_gt_xy, avg_mod1_xy)[0, 1]
corr_uv_mod2 = np.corrcoef(avg_gt_xy, avg_mod2_xy)[0, 1]
corr_uv_mod3 = np.corrcoef(avg_gt_xy, avg_mod3_xy)[0, 1]
corr_uv_mod4 = np.corrcoef(avg_gt_xy, avg_mod4_xy)[0, 1]
corr_uv_mod5 = np.corrcoef(avg_gt_xy, avg_mod5_xy)[0, 1]
corr_uv_mod6 = np.corrcoef(avg_gt_xy, avg_mod6_xy)[0, 1]
corr_uv_mod7 = np.corrcoef(avg_gt_xy, avg_mod7_xy)[0, 1]





# calculate the pearson correlation coefficient
corr_A_1 = stats.pearsonr(Avg_gt_a, Mod1_avg_res_a_)[0]
corr_A_2 = stats.pearsonr(Avg_gt_a, Mod2_avg_res_a_)[0]
corr_A_3 = stats.pearsonr(Avg_gt_a, Mod3_avg_res_a_)[0]
corr_A_4 = stats.pearsonr(Avg_gt_a, Mod4_avg_res_a_)[0]
corr_A_5 = stats.pearsonr(Avg_gt_a, Mod5_avg_res_a_)[0]
corr_A_6 = stats.pearsonr(Avg_gt_a, Mod6_avg_res_a_)[0]
corr_A_7 = stats.pearsonr(Avg_gt_a, Mod7_avg_res_a_)[0]

# calculate the pearson correlation coefficient
corr_V_1 = stats.pearsonr(Avg_gt_v, Mod1_avg_res_v)[0]
corr_V_2 = stats.pearsonr(Avg_gt_v, Mod2_avg_res_v)[0]
corr_V_3 = stats.pearsonr(Avg_gt_v, Mod3_avg_res_v)[0]
corr_V_4 = stats.pearsonr(Avg_gt_v, Mod4_avg_res_v)[0]
corr_V_5 = stats.pearsonr(Avg_gt_v, Mod5_avg_res_v)[0]
corr_V_6 = stats.pearsonr(Avg_gt_v, Mod6_avg_res_v)[0]
corr_V_7 = stats.pearsonr(Avg_gt_v, Mod7_avg_res_v)[0]

# %% [markdown]
# # Analysis between human and GT

# %%
def draw_plot(Avg_gt_a, Avg_gt_v, Mod1_avg_res_a, Mod1_avg_res_v, corr_A_1, corr_V_1, corr_uv_mod1):

    plt.scatter(Avg_gt_a, Avg_gt_v, c='r', marker='o', alpha=0.5, label="GT", s=100)
    plt.scatter(Mod1_avg_res_a, Mod1_avg_res_v, c='b', marker='o', alpha=0.3, label="Res", s=100)
    # set the range of the figure
    plt.ylim(0, 22)
    # show the correlation and corr_uv_ coefficient bold in the figure
    plt.text(20, 22, "Corr_Angle: " + str(round(corr_A_1, 3)) + "\nCorr_Velocity: " + str(round(corr_V_1, 3)) +
            "\nCorr_UV: " + str(round(corr_uv_mod1, 3)),
            fontsize=20, bbox=dict(facecolor='red', alpha=0.4))
    # set color of the yticks to darkgray
    plt.yticks(color='darkgray',alpha=0.4)
    # reduce the density of the yticks
    plt.yticks(np.arange(0, 22, 4))
    plt.legend(loc='lower left')

# draw the polar plot
# remove r label


plt.figure(figsize=(30, 15))
# set font size
plt.rcParams['font.size'] = 20

plt.subplot(2, 4, 1, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod1_avg_res_a, Mod1_avg_res_v, corr_A_1, corr_V_1, corr_uv_mod1)
plt.title("Mod 1")

plt.subplot(2, 4, 2, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod2_avg_res_a, Mod2_avg_res_v, corr_A_2, corr_V_2, corr_uv_mod2)
plt.title("Mod 2")


plt.subplot(2, 4, 3, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod3_avg_res_a, Mod3_avg_res_v, corr_A_3, corr_V_3, corr_uv_mod3)
plt.title("Mod 3")

plt.subplot(2, 4, 4, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod4_avg_res_a, Mod4_avg_res_v, corr_A_4, corr_V_4, corr_uv_mod4)
plt.title("Mod 4")

plt.subplot(2, 4, 5, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod5_avg_res_a, Mod5_avg_res_v, corr_A_5, corr_V_5, corr_uv_mod5)
plt.title("Mod 5")

plt.subplot(2, 4, 6, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod6_avg_res_a, Mod6_avg_res_v, corr_A_6, corr_V_6, corr_uv_mod6)
plt.title("Mod 6")

plt.subplot(2, 4, 7, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod7_avg_res_a, Mod7_avg_res_v, corr_A_7, corr_V_7, corr_uv_mod7)
plt.title("Mod 7")


# average the data
Modall_avg_res_a = np.concatenate([Mod1_avg_res_a, Mod2_avg_res_a, Mod3_avg_res_a, Mod4_avg_res_a, Mod5_avg_res_a,
                                      Mod6_avg_res_a, Mod7_avg_res_a],axis=0)
Modall_avg_res_v = np.concatenate([Mod1_avg_res_v, Mod2_avg_res_v, Mod3_avg_res_v, Mod4_avg_res_v, Mod5_avg_res_v,
                                        Mod6_avg_res_v, Mod7_avg_res_v],axis=0)

Modall_uv = np.concatenate([avg_mod1_xy, avg_mod2_xy, avg_mod3_xy, avg_mod4_xy, avg_mod5_xy, avg_mod6_xy, avg_mod7_xy], axis=0)

mean_corr_uv = np.mean([corr_uv_mod1, corr_uv_mod2, corr_uv_mod3, corr_uv_mod4, corr_uv_mod5, corr_uv_mod6, corr_uv_mod7])
mean_corr_A = np.mean([corr_A_1, corr_A_2, corr_A_3, corr_A_4, corr_A_5, corr_A_6, corr_A_7])
mean_corr_V = np.mean([corr_V_1, corr_V_2, corr_V_3, corr_V_4, corr_V_5, corr_V_6, corr_V_7])



plt.subplot(2, 4, 8, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Modall_avg_res_a, Modall_avg_res_v, mean_corr_A, mean_corr_V, mean_corr_uv)
plt.title("All Mods")
# Out:
# Text(0.5, 1.0, 'All Mods')

# %%
plt.style.use('ggplot')
# set style of the figure to normal

plt.rcParams['font.size'] = 20
plt.rcParams['font.family'] = 'Times New Roman'

# %matplotlib inline
legends = 2 * len(Avg_gt_X)*['Random Noise, Corr = %.3f' %corr_uv_mod1] + \
            2 * len(Avg_gt_X)*['Gaussain Blur, Corr = %.3f' %corr_uv_mod2] + \
            2 * len(Avg_gt_X)*['Water Wave, Corr = %.3f' %corr_uv_mod3] + \
            2 * len(Avg_gt_X)*['Random Phase, Corr = %.3f' %corr_uv_mod4] + \
            2 * len(Avg_gt_X)*['Random Shuffle, Corr = %.3f' %corr_uv_mod5] + \
            2 * len(Avg_gt_X)*['Vortex Field, Corr = %.3f' %corr_uv_mod6] + \
            2 * len(Avg_gt_X)*['Drift-Balance, Corr = %.3f' %corr_uv_mod7]

legends = np.array(legends)
df_line = pd.DataFrame({'UV_Res': np.concatenate([Mod1_avg_res_X, Mod1_avg_res_Y, Mod2_avg_res_X, Mod2_avg_res_Y,
                                                 Mod3_avg_res_X, Mod3_avg_res_Y, Mod4_avg_res_X, Mod4_avg_res_Y,
                                                 Mod5_avg_res_X, Mod5_avg_res_Y, Mod6_avg_res_X, Mod6_avg_res_Y,
                                                    Mod7_avg_res_X, Mod7_avg_res_Y]), 'UV_GT': np.concatenate([Avg_gt_X, Avg_gt_Y]*7, axis=0), 
                        'Modulation': legends}) 
                   
plt.figure(figsize=(15, 15))                                                                                                     
sns.jointplot(x='UV_GT', y='UV_Res', data=df_line, hue='Modulation',palette="Set1",alpha = 0.4,marker='o',s=150)
plt.xlabel('Ground Truth (UV)')
plt.ylabel('Response (UV)')
plt.show()


plt.rcParams['font.size'] = 40
plt.rcParams['font.family'] = 'Times New Roman'
lmplots = sns.lmplot(x='UV_GT', y='UV_Res', data=df_line, hue='Modulation',palette="Set1",scatter_kws={"s": 50, 'alpha':0.4},legend=True, truncate=True, line_kws={'linewidth': 4}
                     ,height=6, aspect=1.5, legend_out=False)
plt.xlabel('Ground Truth (UV)', fontsize=25)
plt.ylabel('Response (UV)', fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(loc='upper left', 
           fontsize=15)
# plt.legend(['Modulation 1, Correlation = %.3f' %corr_uv_mod1, 'Modulation 2, Correlation = %.3f' %corr_uv_mod2,
#             'Modulation 3, Correlation = %.3f' %corr_uv_mod3, 'Modulation 4, Correlation = %.3f' %corr_uv_mod4,
#             'Modulation 5, Correlation = %.3f' %corr_uv_mod5, 'Modulation 6, Correlation = %.3f' %corr_uv_mod6,
#             'Modulation 7, Correlation = %.3f' %corr_uv_mod7], loc='upper left', fontsize=15)

# bold the axis
plt.grid(True)
plt.setp(lmplots.ax.get_xticklabels(), weight="bold")
plt.setp(lmplots.ax.get_yticklabels(), weight="bold")
plt.tight_layout()

plt.show()
# Out:
# c:\Users\sun96\anaconda3\envs\pytorch-base\lib\site-packages\seaborn\regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Analysis between Model and GT

# %%
file_root = os.path.abspath(os.path.join(os.getcwd(), "../data/model/dual"))
dfx = pd.read_csv(file_root + '/dual_final_csv_x.csv', encoding='utf-8')
dfy = pd.read_csv(file_root + '/dual_final_csv_y.csv', encoding='utf-8')
# select the model here

Mod1_model_X = dfx['type1'].values
Mod2_model_X = dfx['type2'].values
Mod3_model_X = dfx['type3'].values
Mod4_model_X = dfx['type4'].values
Mod5_model_X = dfx['type5'].values
Mod6_model_X = dfx['type6'].values
Mod7_model_X = dfx['type7'].values

Mod1_model_Y = dfy['type1'].values
Mod2_model_Y = dfy['type2'].values
Mod3_model_Y = dfy['type3'].values
Mod4_model_Y = dfy['type4'].values
Mod5_model_Y = dfy['type5'].values
Mod6_model_Y = dfy['type6'].values
Mod7_model_Y = dfy['type7'].values

# to numpy
Mod1_model_X, Mod1_model_Y = np.array(Mod1_model_X), np.array(Mod1_model_Y)
Mod2_model_X, Mod2_model_Y = np.array(Mod2_model_X), np.array(Mod2_model_Y)
Mod3_model_X, Mod3_model_Y = np.array(Mod3_model_X), np.array(Mod3_model_Y)
Mod4_model_X, Mod4_model_Y = np.array(Mod4_model_X), np.array(Mod4_model_Y)
Mod5_model_X, Mod5_model_Y = np.array(Mod5_model_X), np.array(Mod5_model_Y)
Mod6_model_X, Mod6_model_Y = np.array(Mod6_model_X), np.array(Mod6_model_Y)
Mod7_model_X, Mod7_model_Y = np.array(Mod7_model_X), np.array(Mod7_model_Y)

# cartesian to polar
Mod1_model_a, Mod1_model_v = cartesian2polar(Mod1_model_X, Mod1_model_Y)
Mod2_model_a, Mod2_model_v = cartesian2polar(Mod2_model_X, Mod2_model_Y)
Mod3_model_a, Mod3_model_v = cartesian2polar(Mod3_model_X, Mod3_model_Y)
Mod4_model_a, Mod4_model_v = cartesian2polar(Mod4_model_X, Mod4_model_Y)
Mod5_model_a, Mod5_model_v = cartesian2polar(Mod5_model_X, Mod5_model_Y)
Mod6_model_a, Mod6_model_v = cartesian2polar(Mod6_model_X, Mod6_model_Y)
Mod7_model_a, Mod7_model_v = cartesian2polar(Mod7_model_X, Mod7_model_Y)

Mod1_model_a, Mod2_model_a, Mod3_model_a, Mod4_model_a, Mod5_model_a, Mod6_model_a, Mod7_model_a, \
    = np.rad2deg(Mod1_model_a), np.rad2deg(Mod2_model_a), \
    np.rad2deg(Mod3_model_a), np.rad2deg(Mod4_model_a), np.rad2deg(Mod5_model_a), np.rad2deg(Mod6_model_a), \
    np.rad2deg(Mod7_model_a),

Mod1_model_XY = np.concatenate((Mod1_model_X, Mod1_model_Y))
Mod2_model_XY = np.concatenate((Mod2_model_X, Mod2_model_Y))
Mod3_model_XY = np.concatenate((Mod3_model_X, Mod3_model_Y))
Mod4_model_XY = np.concatenate((Mod4_model_X, Mod4_model_Y))
Mod5_model_XY = np.concatenate((Mod5_model_X, Mod5_model_Y))
Mod6_model_XY = np.concatenate((Mod6_model_X, Mod6_model_Y))
Mod7_model_XY = np.concatenate((Mod7_model_X, Mod7_model_Y))

corr_uv_mod1 = np.corrcoef(avg_gt_xy, Mod1_model_XY)[0, 1]
corr_uv_mod2 = np.corrcoef(avg_gt_xy, Mod2_model_XY)[0, 1]
corr_uv_mod3 = np.corrcoef(avg_gt_xy, Mod3_model_XY)[0, 1]
corr_uv_mod4 = np.corrcoef(avg_gt_xy, Mod4_model_XY)[0, 1]
corr_uv_mod5 = np.corrcoef(avg_gt_xy, Mod5_model_XY)[0, 1]
corr_uv_mod6 = np.corrcoef(avg_gt_xy, Mod6_model_XY)[0, 1]
corr_uv_mod7 = np.corrcoef(avg_gt_xy, Mod7_model_XY)[0, 1]

corr_A_1 = stats.pearsonr(Avg_gt_a, Mod1_model_a)[0]
corr_A_2 = stats.pearsonr(Avg_gt_a, Mod2_model_a)[0]
corr_A_3 = stats.pearsonr(Avg_gt_a, Mod3_model_a)[0]
corr_A_4 = stats.pearsonr(Avg_gt_a, Mod4_model_a)[0]
corr_A_5 = stats.pearsonr(Avg_gt_a, Mod5_model_a)[0]
corr_A_6 = stats.pearsonr(Avg_gt_a, Mod6_model_a)[0]
corr_A_7 = stats.pearsonr(Avg_gt_a, Mod7_model_a)[0]

corr_V_1 = stats.pearsonr(Avg_gt_v, Mod1_model_v)[0]
corr_V_2 = stats.pearsonr(Avg_gt_v, Mod2_model_v)[0]
corr_V_3 = stats.pearsonr(Avg_gt_v, Mod3_model_v)[0]
corr_V_4 = stats.pearsonr(Avg_gt_v, Mod4_model_v)[0]
corr_V_5 = stats.pearsonr(Avg_gt_v, Mod5_model_v)[0]
corr_V_6 = stats.pearsonr(Avg_gt_v, Mod6_model_v)[0]
corr_V_7 = stats.pearsonr(Avg_gt_v, Mod7_model_v)[0]

# %%
def draw_plot(Avg_gt_a, Avg_gt_v, Mod1_avg_res_a, Mod1_avg_res_v, corr_A_1, corr_V_1, corr_uv_mod1):

    plt.scatter(Avg_gt_a, Avg_gt_v, c='r', marker='o', alpha=0.5, label="GT", s=100)
    plt.scatter(Mod1_avg_res_a, Mod1_avg_res_v, c='b', marker='o', alpha=0.3, label="Model", s=100)
    # set the range of the figure
    plt.ylim(0, 22)
    # show the correlation and corr_uv_ coefficient bold in the figure
    plt.text(20, 22, "Corr_Angle: " + str(round(corr_A_1, 3)) + "\nCorr_Velocity: " + str(round(corr_V_1, 3)) +
            "\nCorr_UV: " + str(round(corr_uv_mod1, 3)),
            fontsize=15, bbox=dict(facecolor='red', alpha=0.5))
    # set color of the yticks to darkgray
    plt.yticks(color='darkgray')
    # reduce the density of the yticks
    plt.yticks(np.arange(0, 22, 4))
    plt.legend(loc='lower left')

# draw the polar plot
# remove r label


plt.figure(figsize=(25, 15))
plt.rcParams['font.size'] = 10
plt.rcParams['font.family'] = 'Times New Roman'
plt.subplot(2, 4, 1, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod1_avg_res_a, Mod1_avg_res_v, corr_A_1, corr_V_1, corr_uv_mod1)
plt.title("Modulation 1")

plt.subplot(2, 4, 2, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod2_avg_res_a, Mod2_avg_res_v, corr_A_2, corr_V_2, corr_uv_mod2)
plt.title("Modulation 2")


plt.subplot(2, 4, 3, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod3_avg_res_a, Mod3_avg_res_v, corr_A_3, corr_V_3, corr_uv_mod3)
plt.title("Modulation 3")

plt.subplot(2, 4, 4, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod4_avg_res_a, Mod4_avg_res_v, corr_A_4, corr_V_4, corr_uv_mod4)
plt.title("Modulation 4")

plt.subplot(2, 4, 5, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod5_avg_res_a, Mod5_avg_res_v, corr_A_5, corr_V_5, corr_uv_mod5)
plt.title("Modulation 5")

plt.subplot(2, 4, 6, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod6_avg_res_a, Mod6_avg_res_v, corr_A_6, corr_V_6, corr_uv_mod6)
plt.title("Modulation 6")

plt.subplot(2, 4, 7, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Mod7_avg_res_a, Mod7_avg_res_v, corr_A_7, corr_V_7, corr_uv_mod7)
plt.title("Modulation 7")


# average the data
Modall_avg_res_a = np.concatenate([Mod1_avg_res_a, Mod2_avg_res_a, Mod3_avg_res_a, Mod4_avg_res_a, Mod5_avg_res_a,
                                      Mod6_avg_res_a, Mod7_avg_res_a],axis=0)
Modall_avg_res_v = np.concatenate([Mod1_avg_res_v, Mod2_avg_res_v, Mod3_avg_res_v, Mod4_avg_res_v, Mod5_avg_res_v,
                                        Mod6_avg_res_v, Mod7_avg_res_v],axis=0)

Modall_uv = np.concatenate([Mod1_model_XY, Mod2_model_XY, Mod3_model_XY, Mod4_model_XY, Mod5_model_XY,
                                        Mod6_model_XY, Mod7_model_XY],axis=0)

mean_corr_uv = np.mean([corr_uv_mod1, corr_uv_mod2, corr_uv_mod3, corr_uv_mod4, corr_uv_mod5, corr_uv_mod6, corr_uv_mod7])
mean_corr_A = np.mean([corr_A_1, corr_A_2, corr_A_3, corr_A_4, corr_A_5, corr_A_6, corr_A_7])
mean_corr_V = np.mean([corr_V_1, corr_V_2, corr_V_3, corr_V_4, corr_V_5, corr_V_6, corr_V_7])



plt.subplot(2, 4, 8, projection='polar')
draw_plot(Avg_gt_a, Avg_gt_v, Modall_avg_res_a, Modall_avg_res_v, mean_corr_A, mean_corr_V, mean_corr_uv)
plt.title("Modulation 7")
# Out:
# Text(0.5, 1.0, 'Modulation 7')

# %%
df_line = pd.DataFrame({'UV_Res': np.concatenate([Mod1_model_X, Mod1_model_Y, Mod2_model_X, Mod2_model_Y,
                                                   Mod3_model_X, Mod3_model_Y, Mod4_model_X, Mod4_model_Y,
                                                   Mod5_model_X, Mod5_model_Y, Mod6_model_X, Mod6_model_Y,
                                                      Mod7_model_X, Mod7_model_Y]), 'UV_GT': np.concatenate([Avg_gt_X, Avg_gt_Y]*7, axis=0), 'Modulation'
                           : np.concatenate([np.ones(len(Avg_gt_X)*2)*1, np.ones(len(Avg_gt_X)*2)*2, np.ones(len(Avg_gt_X)*2)*3,
                                             np.ones(len(Avg_gt_X)*2)*4, np.ones(len(Avg_gt_X)*2)*5, np.ones(len(Avg_gt_X)*2)*6,
                                             np.ones(len(Avg_gt_X)*2)*7], axis=0)})


                                                                                                              

sns.jointplot(x='UV_GT', y='UV_Res', data=df_line, hue='Modulation',palette="Set1",alpha = 0.4,marker='o',s=100)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = 'Times New Roman'
plt.xlabel('Ground Truth')
plt.ylabel('Response')
plt.show()


sns.set_style('whitegrid')
plt.style.use('ggplot')
lmplots = sns.lmplot(x='UV_GT', y='UV_Res', data=df_line, hue='Modulation',palette="Set1",scatter_kws={"s": 30, 'alpha':0.4},legend=True, truncate=True, line_kws={'linewidth': 2}
                     ,height=6, aspect=1.5, legend_out=False)
plt.xlabel('Ground Truth')
plt.xlim(-15, 15)
plt.ylim(-15, 15)
plt.ylabel('Response')
plt.show()

# draw correlation coefficient of each modulation
plt.figure(figsize=(15, 10))
plt.rcParams['font.size'] = 20
plt.rcParams['font.family'] = 'Times New Roman'
plt.bar(np.arange(7), [corr_uv_mod1, corr_uv_mod2, corr_uv_mod3, corr_uv_mod4, corr_uv_mod5, corr_uv_mod6, corr_uv_mod7])
plt.xticks(np.arange(7), ['Modulation 1', 'Modulation 2', 'Modulation 3', 'Modulation 4', 'Modulation 5', 'Modulation 6', 'Modulation 7'])
plt.ylabel('Correlation Coefficient')
plt.title('Correlation Coefficient of Each Modulation')
plt.show()
mean_corr_uv = np.mean([corr_uv_mod1, corr_uv_mod2, corr_uv_mod3, corr_uv_mod4, corr_uv_mod5, corr_uv_mod6, corr_uv_mod7])
# print the mean correlation coefficient and std
print("Mean Correlation Coefficient across all modulations: %.3f" %mean_corr_uv)
print("Standard Deviation of Correlation Coefficient across all modulations: %.3f" %np.std([corr_uv_mod1, corr_uv_mod2, corr_uv_mod3, corr_uv_mod4, corr_uv_mod5, corr_uv_mod6, corr_uv_mod7]))
# Out:
# c:\Users\sun96\anaconda3\envs\pytorch-base\lib\site-packages\seaborn\regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Mean Correlation Coefficient across all modulations: 0.934
# Standard Deviation of Correlation Coefficient across all modulations: 0.021

# %% [markdown]
# # Analysis Between the Human and Model

# %%
corr1_uv_human_model = np.corrcoef(avg_mod1_xy, Mod1_model_XY)[0, 1]
corr2_uv_human_model = np.corrcoef(avg_mod2_xy, Mod2_model_XY)[0, 1]
corr3_uv_human_model = np.corrcoef(avg_mod3_xy, Mod3_model_XY)[0, 1]
corr4_uv_human_model = np.corrcoef(avg_mod4_xy, Mod4_model_XY)[0, 1]
corr5_uv_human_model = np.corrcoef(avg_mod5_xy, Mod5_model_XY)[0, 1]
corr6_uv_human_model = np.corrcoef(avg_mod6_xy, Mod6_model_XY)[0, 1]
corr7_uv_human_model = np.corrcoef(avg_mod7_xy, Mod7_model_XY)[0, 1]


corr1_A_human_model = stats.pearsonr(Mod1_avg_res_a, Mod1_model_a)[0]
corr2_A_human_model = stats.pearsonr(Mod2_avg_res_a, Mod2_model_a)[0]
corr3_A_human_model = stats.pearsonr(Mod3_avg_res_a, Mod3_model_a)[0]
corr4_A_human_model = stats.pearsonr(Mod4_avg_res_a, Mod4_model_a)[0]
corr5_A_human_model = stats.pearsonr(Mod5_avg_res_a, Mod5_model_a)[0]
corr6_A_human_model = stats.pearsonr(Mod6_avg_res_a, Mod6_model_a)[0]
corr7_A_human_model = stats.pearsonr(Mod7_avg_res_a, Mod7_model_a)[0]


corr1_V_human_model = stats.pearsonr(Mod1_avg_res_v, Mod1_model_v)[0]
corr2_V_human_model = stats.pearsonr(Mod2_avg_res_v, Mod2_model_v)[0]
corr3_V_human_model = stats.pearsonr(Mod3_avg_res_v, Mod3_model_v)[0]
corr4_V_human_model = stats.pearsonr(Mod4_avg_res_v, Mod4_model_v)[0]
corr5_V_human_model = stats.pearsonr(Mod5_avg_res_v, Mod5_model_v)[0]
corr6_V_human_model = stats.pearsonr(Mod6_avg_res_v, Mod6_model_v)[0]
corr7_V_human_model = stats.pearsonr(Mod7_avg_res_v, Mod7_model_v)[0]




# average the data
Modall_avg_res_a = np.concatenate([Mod1_avg_res_a, Mod2_avg_res_a, Mod3_avg_res_a, Mod4_avg_res_a, Mod5_avg_res_a,
                                          Mod6_avg_res_a, Mod7_avg_res_a],axis=0)
Modall_avg_res_v = np.concatenate([Mod1_avg_res_v, Mod2_avg_res_v, Mod3_avg_res_v, Mod4_avg_res_v, Mod5_avg_res_v,
                                        Mod6_avg_res_v, Mod7_avg_res_v],axis=0)

Modall_uv = np.concatenate([Mod1_model_XY, Mod2_model_XY, Mod3_model_XY, Mod4_model_XY, Mod5_model_XY,
                                        Mod6_model_XY, Mod7_model_XY],axis=0)

Modall_model_a = np.concatenate([Mod1_model_a, Mod2_model_a, Mod3_model_a, Mod4_model_a, Mod5_model_a,
                                        Mod6_model_a, Mod7_model_a],axis=0)
Modall_model_v = np.concatenate([Mod1_model_v, Mod2_model_v, Mod3_model_v, Mod4_model_v, Mod5_model_v,
                                        Mod6_model_v, Mod7_model_v],axis=0)
Modall_human_a = np.concatenate([Mod1_avg_res_a, Mod2_avg_res_a, Mod3_avg_res_a, Mod4_avg_res_a, Mod5_avg_res_a,
                                        Mod6_avg_res_a, Mod7_avg_res_a],axis=0)

mean_corr_uv = np.mean([corr1_uv_human_model, corr2_uv_human_model, corr3_uv_human_model, corr4_uv_human_model, corr5_uv_human_model, corr6_uv_human_model, corr7_uv_human_model])
mean_corr_A = np.mean([corr1_A_human_model, corr2_A_human_model, corr3_A_human_model, corr4_A_human_model, corr5_A_human_model, corr6_A_human_model, corr7_A_human_model])

# normalize the velocity to std 1

std_human = np.max(Modall_avg_res_v)
std_model = np.max(Modall_model_v)

# Modall_avg_res_v = Modall_avg_res_v / std_human
# Modall_model_v = Modall_model_v / std_model




def draw_plot(Avg_gt_a, Avg_gt_v, Mod1_avg_res_a, Mod1_avg_res_v, corr_A_1, corr_V_1, corr_uv_mod1):
        Avg_gt_v_ = Avg_gt_v / std_human
        Mod1_avg_res_v_ = Mod1_avg_res_v /std_model
        plt.scatter(Avg_gt_a, Avg_gt_v_, c='r', marker='o', alpha=0.3, label="Human", s=100)
        plt.scatter(Mod1_avg_res_a, Mod1_avg_res_v_, c='b', marker='o', alpha=0.3, label="Model", s=100)
        # set the range of the figure
        plt.ylim(0, 1.2)
        # show the correlation and corr_uv_ coefficient bold in the figure
        plt.text(1, 1, "Corr_Angle: " + str(round(corr_A_1, 3)) + "\nCorr_Velocity: " + str(round(corr_V_1, 3)) +
                "\nCorr_UV: " + str(round(corr_uv_mod1, 3)),
                fontsize=15, bbox=dict(facecolor='red', alpha=0.5))
        # set color of the yticks to darkgray
        plt.yticks(color='darkgray')
        # reduce the density of the yticks
        # plt.yticks(np.arange(0, 1.2, 4))
        plt.legend(loc='lower left')

# draw the polar plot
# remove r label

plt.figure(figsize=(25, 15))

plt.subplot(2, 4, 1, projection='polar')
draw_plot(Mod1_avg_res_a, Mod1_avg_res_v, Mod1_model_a, Mod1_model_v, corr1_A_human_model, corr1_V_human_model, corr1_uv_human_model)
plt.title("Modulation 1")

plt.subplot(2, 4, 2, projection='polar')
draw_plot(Mod2_avg_res_a, Mod2_avg_res_v, Mod2_model_a, Mod2_model_v, corr2_A_human_model, corr2_V_human_model, corr2_uv_human_model)
plt.title("Modulation 2")

plt.subplot(2, 4, 3, projection='polar')
draw_plot(Mod3_avg_res_a, Mod3_avg_res_v, Mod3_model_a, Mod3_model_v, corr3_A_human_model, corr3_V_human_model, corr3_uv_human_model)
plt.title("Modulation 3")

plt.subplot(2, 4, 4, projection='polar')
draw_plot(Mod4_avg_res_a, Mod4_avg_res_v, Mod4_model_a, Mod4_model_v, corr4_A_human_model, corr4_V_human_model, corr4_uv_human_model)
plt.title("Modulation 4")

plt.subplot(2, 4, 5, projection='polar')
draw_plot(Mod5_avg_res_a, Mod5_avg_res_v, Mod5_model_a, Mod5_model_v, corr5_A_human_model, corr5_V_human_model, corr5_uv_human_model)
plt.title("Modulation 5")

plt.subplot(2, 4, 6, projection='polar')
draw_plot(Mod6_avg_res_a, Mod6_avg_res_v, Mod6_model_a, Mod6_model_v, corr6_A_human_model, corr6_V_human_model, corr6_uv_human_model)
plt.title("Modulation 6")

plt.subplot(2, 4, 7, projection='polar')
draw_plot(Mod7_avg_res_a, Mod7_avg_res_v, Mod7_model_a, Mod7_model_v, corr7_A_human_model, corr7_V_human_model, corr7_uv_human_model)
plt.title("Modulation 7")




plt.subplot(2, 4, 8, projection='polar')
draw_plot(Modall_avg_res_a, Modall_avg_res_v, Modall_model_a, Modall_model_v, mean_corr_A, mean_corr_V, mean_corr_uv)
plt.title("ALL")
# Out:
# Text(0.5, 1.0, 'ALL')

# %% [markdown]
# # Join Analysis Between Model and Human

# %%
import pingouin as pg
# calculate the partial correlation coefficient between the Mod1_model_XY and avg_mod1_xy while controlling the avg_gt_xy

# partial correlation coefficient
df_partial = pd.DataFrame({'Mod1_model_XY': Mod1_model_XY, 'avg_mod1_xy': avg_mod1_xy, 'avg_gt_xy': avg_gt_xy})
partial_corr1 = pg.partial_corr(data=df_partial, x='Mod1_model_XY', y='avg_mod1_xy', covar='avg_gt_xy')
print(partial_corr1)

# partial correlation coefficient
df_partial = pd.DataFrame({'Mod2_model_XY': Mod2_model_XY, 'avg_mod2_xy': avg_mod2_xy, 'avg_gt_xy': avg_gt_xy})
partial_corr2 = pg.partial_corr(data=df_partial, x='Mod2_model_XY', y='avg_mod2_xy', covar='avg_gt_xy')
print(partial_corr2)

# partial correlation coefficient
df_partial = pd.DataFrame({'Mod3_model_XY': Mod3_model_XY, 'avg_mod3_xy': avg_mod3_xy, 'avg_gt_xy': avg_gt_xy})
partial_corr3 = pg.partial_corr(data=df_partial, x='Mod3_model_XY', y='avg_mod3_xy', covar='avg_gt_xy')
print(partial_corr3)

# partial correlation coefficient
df_partial = pd.DataFrame({'Mod4_model_XY': Mod4_model_XY, 'avg_mod4_xy': avg_mod4_xy, 'avg_gt_xy': avg_gt_xy})
partial_corr4 = pg.partial_corr(data=df_partial, x='Mod4_model_XY', y='avg_mod4_xy', covar='avg_gt_xy')
print(partial_corr4)

# partial correlation coefficient
df_partial = pd.DataFrame({'Mod5_model_XY': Mod5_model_XY, 'avg_mod5_xy': avg_mod5_xy, 'avg_gt_xy': avg_gt_xy})
partial_corr5 = pg.partial_corr(data=df_partial, x='Mod5_model_XY', y='avg_mod5_xy', covar='avg_gt_xy')
print(partial_corr5)

# partial correlation coefficient
df_partial = pd.DataFrame({'Mod6_model_XY': Mod6_model_XY, 'avg_mod6_xy': avg_mod6_xy, 'avg_gt_xy': avg_gt_xy})
partial_corr6 = pg.partial_corr(data=df_partial, x='Mod6_model_XY', y='avg_mod6_xy', covar='avg_gt_xy')
print(partial_corr6)


# partial correlation coefficient
df_partial = pd.DataFrame({'Mod7_model_XY': Mod7_model_XY, 'avg_mod7_xy': avg_mod7_xy, 'avg_gt_xy': avg_gt_xy})
partial_corr7 = pg.partial_corr(data=df_partial, x='Mod7_model_XY', y='avg_mod7_xy', covar='avg_gt_xy')
print(partial_corr7)




corr1 = pg.corr(Mod1_model_XY, avg_mod1_xy)
corr2 = pg.corr(Mod2_model_XY, avg_mod2_xy)
corr3 = pg.corr(Mod3_model_XY, avg_mod3_xy)
corr4 = pg.corr(Mod4_model_XY, avg_mod4_xy)
corr5 = pg.corr(Mod5_model_XY, avg_mod5_xy)
corr6 = pg.corr(Mod6_model_XY, avg_mod6_xy)
corr7 = pg.corr(Mod7_model_XY, avg_mod7_xy)

corr1_r = float(corr1['r'].values)
corr1_interval = corr1['CI95%'].values[0]
corr2_r = float(corr2['r'].values)
corr2_interval = corr2['CI95%'].values[0]
corr3_r = float(corr3['r'].values)
corr3_interval = corr3['CI95%'].values[0]
corr4_r = float(corr4['r'].values)
corr4_interval = corr4['CI95%'].values[0]
corr5_r = float(corr5['r'].values)
corr5_interval = corr5['CI95%'].values[0]
corr6_r = float(corr6['r'].values)
corr6_interval = corr6['CI95%'].values[0]
corr7_r = float(corr7['r'].values)
corr7_interval = corr7['CI95%'].values[0]


corr1_model_gt = pg.corr(Mod1_model_XY, avg_gt_xy)
corr2_model_gt = pg.corr(Mod2_model_XY, avg_gt_xy)
corr3_model_gt = pg.corr(Mod3_model_XY, avg_gt_xy)
corr4_model_gt = pg.corr(Mod4_model_XY, avg_gt_xy)
corr5_model_gt = pg.corr(Mod5_model_XY, avg_gt_xy)
corr6_model_gt = pg.corr(Mod6_model_XY, avg_gt_xy)
corr7_model_gt = pg.corr(Mod7_model_XY, avg_gt_xy)

corr1_model_gt_r = float(corr1_model_gt['r'].values)
corr1_model_gt_interval = corr1_model_gt['CI95%'].values[0]
corr2_model_gt_r = float(corr2_model_gt['r'].values)
corr2_model_gt_interval = corr2_model_gt['CI95%'].values[0]
corr3_model_gt_r = float(corr3_model_gt['r'].values)
corr3_model_gt_interval = corr3_model_gt['CI95%'].values[0]
corr4_model_gt_r = float(corr4_model_gt['r'].values)
corr4_model_gt_interval = corr4_model_gt['CI95%'].values[0]
corr5_model_gt_r = float(corr5_model_gt['r'].values)
corr5_model_gt_interval = corr5_model_gt['CI95%'].values[0]
corr6_model_gt_r = float(corr6_model_gt['r'].values)
corr6_model_gt_interval = corr6_model_gt['CI95%'].values[0]
corr7_model_gt_r = float(corr7_model_gt['r'].values)
corr7_model_gt_interval = corr7_model_gt['CI95%'].values[0]

partial_corr1_r = float(partial_corr1['r'].values)
partial_corr1_interval = partial_corr1['CI95%'].values[0]
partial_corr2_r = float(partial_corr2['r'].values)
partial_corr2_interval = partial_corr2['CI95%'].values[0]
partial_corr3_r = float(partial_corr3['r'].values)
partial_corr3_interval = partial_corr3['CI95%'].values[0]
partial_corr4_r = float(partial_corr4['r'].values)
partial_corr4_interval = partial_corr4['CI95%'].values[0]
partial_corr5_r = float(partial_corr5['r'].values)
partial_corr5_interval = partial_corr5['CI95%'].values[0]
partial_corr6_r = float(partial_corr6['r'].values)
partial_corr6_interval = partial_corr6['CI95%'].values[0]
partial_corr7_r = float(partial_corr7['r'].values)
partial_corr7_interval = partial_corr7['CI95%'].values[0]
# Out:
#           n         r          CI95%     p-val
# pearson  80 -0.003442  [-0.22, 0.22]  0.975984
#           n         r          CI95%     p-val
# pearson  80  0.130007  [-0.09, 0.34]  0.253469
#           n         r         CI95%     p-val
# pearson  80  0.231363  [0.01, 0.43]  0.040214
#           n         r          CI95%     p-val
# pearson  80  0.032422  [-0.19, 0.25]  0.776676
#           n         r          CI95%     p-val
# pearson  80  0.115754  [-0.11, 0.33]  0.309696
#           n         r         CI95%     p-val
# pearson  80  0.264295  [0.05, 0.46]  0.018588
#           n         r          CI95%     p-val
# pearson  80 -0.037951  [-0.26, 0.18]  0.739843

# %%
import seaborn as sns

figure = plt.figure(figsize=(10, 10))

# # draw sns barplot of the partial correlation coefficient and the correlation coefficient 
# sns.barplot(x=['Mod1', 'Mod2', 'Mod3', 'Mod4', 'Mod5', 'Mod6', 'Mod7'],
#             y=[float(partial_corr1['r'].values), float(partial_corr2['r'].values), float(partial_corr3['r'].values),
#                float(partial_corr4['r'].values), float(partial_corr5['r'].values), float(partial_corr6['r'].values),
#                float(partial_corr7['r'].values)])
# plt.ylim(-1, 1)
# plt.ylabel('Partial Correlation Coefficient')
# plt.show()


#  draw sns barplot of the partial correlation coefficient and the correlation coefficient with two columns
df = pd.DataFrame({'Modulation': ['Mod1', 'Mod2', 'Mod3', 'Mod4', 'Mod5', 'Mod6', 'Mod7'],
                     'Corr_Model_Hum': [corr1_r, corr2_r, corr3_r, corr4_r, corr5_r, corr6_r, corr7_r],
                     'Corr_Model_GT': [corr1_model_gt_r, corr2_model_gt_r, corr3_model_gt_r, corr4_model_gt_r,
                                        corr5_model_gt_r, corr6_model_gt_r, corr7_model_gt_r]
                                       
                                       })


df = pd.melt(df, id_vars=['Modulation'], value_vars=['Corr_Model_Hum', 'Corr_Model_GT'])
sns.barplot(x='Modulation', y='value', hue='variable', data=df)
# plot the error bar using the confidence interval

plt.ylim(-0.5, 1)
plt.ylabel('Correlation Coefficient', fontsize=20,)
plt.xlabel('Modulation', fontsize=20)
# set font size of x and y xicks
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)
# set times New Roman font
plt.rcParams['font.sans-serif'] = ['Times New Roman']
# set the legend font size
plt.legend(fontsize=15)

plt.show()
